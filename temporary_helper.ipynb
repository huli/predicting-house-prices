# %%
import pandas as pd

# %%
training = pd.read_csv('data/train.csv')

# %%
training.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000
# 25%       5.000000  1954.000000   1967.000000     0.000000     0.000000
# 50%       5.000000  1973.000000   1994.000000     0.000000   383.500000
# 75%       6.000000  2000.000000   2004.000000   166.000000   712.250000
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000
#
#            ...         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  \
# count      ...        1460.000000  1460.000000    1460.000000  1460.000000
# mean       ...          94.244521    46.660274      21.954110     3.409589
# std        ...         125.338794    66.256028      61.119149    29.317331
# min        ...           0.000000     0.000000       0.000000     0.000000
# 25%        ...           0.000000     0.000000       0.000000     0.000000
# 50%        ...           0.000000    25.000000       0.000000     0.000000
# 75%        ...         168.000000    68.000000       0.000000     0.000000
# max        ...         857.000000   547.000000     552.000000   508.000000
#
#        ScreenPorch     PoolArea       MiscVal       MoSold       YrSold  \
# count  1460.000000  1460.000000   1460.000000  1460.000000  1460.000000
# mean     15.060959     2.758904     43.489041     6.321918  2007.815753
# std      55.757415    40.177307    496.123024     2.703626     1.328095
# min       0.000000     0.000000      0.000000     1.000000  2006.000000
# 25%       0.000000     0.000000      0.000000     5.000000  2007.000000
# 50%       0.000000     0.000000      0.000000     6.000000  2008.000000
# 75%       0.000000     0.000000      0.000000     8.000000  2009.000000
# max     480.000000   738.000000  15500.000000    12.000000  2010.000000
#
#            SalePrice
# count    1460.000000
# mean   180921.195890
# std     79442.502883
# min     34900.000000
# 25%    129975.000000
# 50%    163000.000000
# 75%    214000.000000
# max    755000.000000
#
# [8 rows x 38 columns]

# %%
training.shape
# Out:
# (1460, 81)

# %%
training.select_dtypes(exclude=['object']) \
    .loc[:, ['GrLivArea', 'OverallQual', 'YearBuilt', 'FullBath', 'Fireplaces', 'PoolArea', 'GarageCars', 'SalePrice']].describe()
# Out:
#          GrLivArea  OverallQual    YearBuilt     FullBath   Fireplaces  \
# count  1460.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean   1515.463699     6.099315  1971.267808     1.565068     0.613014
# std     525.480383     1.382997    30.202904     0.550916     0.644666
# min     334.000000     1.000000  1872.000000     0.000000     0.000000
# 25%    1129.500000     5.000000  1954.000000     1.000000     0.000000
# 50%    1464.000000     6.000000  1973.000000     2.000000     1.000000
# 75%    1776.750000     7.000000  2000.000000     2.000000     1.000000
# max    5642.000000    10.000000  2010.000000     3.000000     3.000000
#
#           PoolArea   GarageCars      SalePrice
# count  1460.000000  1460.000000    1460.000000
# mean      2.758904     1.767123  180921.195890
# std      40.177307     0.747315   79442.502883
# min       0.000000     0.000000   34900.000000
# 25%       0.000000     1.000000  129975.000000
# 50%       0.000000     2.000000  163000.000000
# 75%       0.000000     2.000000  214000.000000
# max     738.000000     4.000000  755000.000000

# %%
training.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
training.select_dtypes(exclude=['object']) \
    .loc[:, ['GrLivArea', 'OverallQual', 'YearBuilt', 'PoolArea', 'CentralAir', 'Neighborhood', 'CentralAir', 'SalePrice']].head(10)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1472: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
#    GrLivArea  OverallQual  YearBuilt  PoolArea  CentralAir  Neighborhood  \
# 0       1710            7       2003         0         NaN           NaN
# 1       1262            6       1976         0         NaN           NaN
# 2       1786            7       2001         0         NaN           NaN
# 3       1717            7       1915         0         NaN           NaN
# 4       2198            8       2000         0         NaN           NaN
# 5       1362            5       1993         0         NaN           NaN
# 6       1694            8       2004         0         NaN           NaN
# 7       2090            7       1973         0         NaN           NaN
# 8       1774            7       1931         0         NaN           NaN
# 9       1077            5       1939         0         NaN           NaN
#
#    CentralAir  SalePrice
# 0         NaN     208500
# 1         NaN     181500
# 2         NaN     223500
# 3         NaN     140000
# 4         NaN     250000
# 5         NaN     143000
# 6         NaN     307000
# 7         NaN     200000
# 8         NaN     129900
# 9         NaN     118000

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
sns.set()

corrmat = pd.read_csv('data/train.csv').drop(['Id'], axis=1).corr()
plt.subplots(figsize=(16,12))
plt.title('Heatmap of correlations between features', )
sns.heatmap(corrmat, vmax=0.9, square=True)
plt.show()

# %%
import numpy as np
X = training
import matplotlib.dates as mdates
import locale
locale.setlocale(locale.LC_ALL, 'de-CH')
thousand_formatter = plt.FuncFormatter(lambda x, _ : locale.format("%d", x, grouping=True))

fig, ax = plt.subplots(1, figsize=(10,8))
ax.scatter(X['GrLivArea'], X['SalePrice'], alpha=.5)
ax.set_xlabel('Living Area (above ground)')
ax.set_ylabel('Price in $')
ax.yaxis.set_major_formatter(thousand_formatter)
ax.xaxis.set_major_formatter(thousand_formatter)
ax.axvline(4000, linestyle='--', linewidth=1)
ax.text(4600, 360000, 'outliers')
plt.show()

# %%
from sklearn.preprocessing import Imputer
def fill_numerical_nans(X_val, mean_columns, zero_columns):
    mean_imputer = Imputer(missing_values='NaN', strategy='mean', axis=0)
    mean_imputer = mean_imputer.fit(X_val.loc[:, mean_columns])
    X_new = X_val.copy()
    X_new.loc[:, mean_columns] = mean_imputer.transform(X_val.loc[:, mean_columns])
    X_new.loc[:, zero_columns] = X_new.loc[:, zero_columns].fillna(value=0)
    return X_new

# %%
X_numerical = X.select_dtypes(exclude=['object']).drop('Id', axis=1)
X_numerical = fill_numerical_nans(X_numerical, ['LotFrontage'], ['MasVnrArea', 'GarageYrBlt'])

# %%
X_numerical['YrSold'].min()
# Out:
# 2006

# %%
sns.set(font_scale=1.5)

# %%
fig, axes = plt.subplots(6,6, figsize=(15,15))
ix = 1
for ax, feature in zip(axes.ravel(), X_numerical.columns):
    if ix % 6 != 1:
        ax.get_yaxis().set_visible(False)
    ax.ticklabel_format(axis='y', style='sci', scilimits=(-1,1))
    #ax.yaxis.set_major_formatter(thousand_formatter)
    sns.regplot(X_numerical[feature], X['SalePrice'], ax = ax, scatter_kws={'alpha': .3})
    #ax.scatter(X_numerical[feature], X['SalePrice'], alpha=.3)
    ix+=1
plt.tight_layout()
plt.show()
